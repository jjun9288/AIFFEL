# %% [markdown]
# ### 데이터 준비

# %%
import os

data_path = os.getenv('HOME') + '/aiffel/cGAN/data/cityscapes/train/'
print('number of train examples : ', len(os.listdir(data_path)))
# Out:
# number of train examples :  1000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 하나 열어 크기 확인

f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# (256, 256, 3) 크기의 2개의 이미지로 분할해서 사용

import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# ### Data augmentation

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])      # 크롭!
    
    out = image.random_flip_left_right(out)                  # 좌우반전!
    out = image.random_flip_up_down(out)                     # 상하반전!
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)        # 90도 회전!
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ### Generator 구성

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %% [markdown]
# ### Discriminator 구성

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ### 학습 및 테스트

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 200

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 100회 반복마다 손실 출력
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:1.8280
# L1_loss:0.2326
# Discriminator_loss:0.6706
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.3077
# L1_loss:0.2473
# Discriminator_loss:0.7234
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.9549
# L1_loss:0.2125
# Discriminator_loss:0.6771
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.2375
# L1_loss:0.1789
# Discriminator_loss:0.7963
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.5370
# L1_loss:0.2208
# Discriminator_loss:0.7362
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.5256
# L1_loss:0.1877
# Discriminator_loss:0.4486
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.0986
# L1_loss:0.1707
# Discriminator_loss:0.8642
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.4063
# L1_loss:0.2778
# Discriminator_loss:0.7377
#
# EPOCH[5] - STEP[100]
# Generator_loss:0.7962
# L1_loss:0.1867
# Discriminator_loss:1.1469
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.6972
# L1_loss:0.1995
# Discriminator_loss:0.4418
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.0637
# L1_loss:0.2059
# Discriminator_loss:0.4710
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.7331
# L1_loss:0.1979
# Discriminator_loss:0.6985
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.3916
# L1_loss:0.2233
# Discriminator_loss:0.4966
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.9732
# L1_loss:0.1610
# Discriminator_loss:1.1326
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.4673
# L1_loss:0.1861
# Discriminator_loss:0.2786
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.6385
# L1_loss:0.1503
# Discriminator_loss:1.2239
#
# EPOCH[9] - STEP[100]
# Generator_loss:3.1006
# L1_loss:0.1815
# Discriminator_loss:0.3565
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.4644
# L1_loss:0.1596
# Discriminator_loss:0.4485
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.0625
# L1_loss:0.1476
# Discriminator_loss:0.6811
#
# EPOCH[10] - STEP[200]
# Generator_loss:0.5845
# L1_loss:0.1837
# Discriminator_loss:1.4245
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.0042
# L1_loss:0.1584
# Discriminator_loss:0.4366
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.1788
# L1_loss:0.2013
# Discriminator_loss:0.2883
#
# EPOCH[12] - STEP[100]
# Generator_loss:0.6470
# L1_loss:0.1742
# Discriminator_loss:1.3256
#
# EPOCH[12] - STEP[200]
# Generator_loss:2.9099
# L1_loss:0.1596
# Discriminator_loss:1.2275
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.9023
# L1_loss:0.1744
# Discriminator_loss:0.9155
#
# EPOCH[13] - STEP[200]
# Generator_loss:0.4580
# L1_loss:0.1604
# Discriminator_loss:1.2436
#
# EPOCH[14] - STEP[100]
# Generator_loss:1.8932
# L1_loss:0.1700
# Discriminator_loss:0.4898
#
# EPOCH[14] - STEP[200]
# Generator_loss:1.8049
# L1_loss:0.1849
# Discriminator_loss:0.3462
#
# EPOCH[15] - STEP[100]
# Generator_loss:1.5159
# L1_loss:0.1837
# Discriminator_loss:0.4906
#
# EPOCH[15] - STEP[200]
# Generator_loss:1.5040
# L1_loss:0.1604
# Discriminator_loss:0.6021
#
# EPOCH[16] - STEP[100]
# Generator_loss:3.4808
# L1_loss:0.1482
# Discriminator_loss:1.7468
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.3280
# L1_loss:0.1299
# Discriminator_loss:0.5965
#
# EPOCH[17] - STEP[100]
# Generator_loss:2.7856
# L1_loss:0.1644
# Discriminator_loss:0.4352
#
# EPOCH[17] - STEP[200]
# Generator_loss:2.5358
# L1_loss:0.1515
# Discriminator_loss:0.5349
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.7129
# L1_loss:0.1748
# Discriminator_loss:0.4851
#
# EPOCH[18] - STEP[200]
# Generator_loss:2.3028
# L1_loss:0.1658
# Discriminator_loss:0.4078
#
# EPOCH[19] - STEP[100]
# Generator_loss:3.5686
# L1_loss:0.1306
# Discriminator_loss:0.8574
#
# EPOCH[19] - STEP[200]
# Generator_loss:1.5651
# L1_loss:0.1474
# Discriminator_loss:0.5165
#
# EPOCH[20] - STEP[100]
# Generator_loss:1.0758
# L1_loss:0.2226
# Discriminator_loss:0.5835
#
# EPOCH[20] - STEP[200]
# Generator_loss:0.7462
# L1_loss:0.1515
# Discriminator_loss:0.9006
#
# EPOCH[21] - STEP[100]
# Generator_loss:1.8102
# L1_loss:0.1456
# Discriminator_loss:0.4035
#
# EPOCH[21] - STEP[200]
# Generator_loss:3.3306
# L1_loss:0.1997
# Discriminator_loss:0.1042
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.7699
# L1_loss:0.1262
# Discriminator_loss:0.4128
#
# EPOCH[22] - STEP[200]
# Generator_loss:2.3650
# L1_loss:0.1566
# Discriminator_loss:1.2044
#
# EPOCH[23] - STEP[100]
# Generator_loss:2.6643
# L1_loss:0.1753
# Discriminator_loss:0.8606
#
# EPOCH[23] - STEP[200]
# Generator_loss:3.1326
# L1_loss:0.1321
# Discriminator_loss:0.6061
#
# EPOCH[24] - STEP[100]
# Generator_loss:4.0558
# L1_loss:0.1571
# Discriminator_loss:0.1301
#
# EPOCH[24] - STEP[200]
# Generator_loss:1.1188
# L1_loss:0.1399
# Discriminator_loss:0.5574
#
# EPOCH[25] - STEP[100]
# Generator_loss:0.2693
# L1_loss:0.1706
# Discriminator_loss:2.2116
#
# EPOCH[25] - STEP[200]
# Generator_loss:2.6547
# L1_loss:0.1780
# Discriminator_loss:0.6015
#
# EPOCH[26] - STEP[100]
# Generator_loss:2.6007
# L1_loss:0.1341
# Discriminator_loss:0.8160
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.8723
# L1_loss:0.1477
# Discriminator_loss:0.5359
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.9788
# L1_loss:0.1336
# Discriminator_loss:0.6180
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.0690
# L1_loss:0.1294
# Discriminator_loss:1.0878
#
# EPOCH[28] - STEP[100]
# Generator_loss:0.3248
# L1_loss:0.1405
# Discriminator_loss:1.7116
#
# EPOCH[28] - STEP[200]
# Generator_loss:4.1478
# L1_loss:0.1510
# Discriminator_loss:0.4518
#
# EPOCH[29] - STEP[100]
# Generator_loss:1.0954
# L1_loss:0.1807
# Discriminator_loss:0.6621
#
# EPOCH[29] - STEP[200]
# Generator_loss:2.1042
# L1_loss:0.1434
# Discriminator_loss:0.8700
#
# EPOCH[30] - STEP[100]
# Generator_loss:2.4149
# L1_loss:0.1604
# Discriminator_loss:1.1810
#
# EPOCH[30] - STEP[200]
# Generator_loss:3.6995
# L1_loss:0.1401
# Discriminator_loss:0.3124
#
# EPOCH[31] - STEP[100]
# Generator_loss:2.2299
# L1_loss:0.1981
# Discriminator_loss:0.2733
#
# EPOCH[31] - STEP[200]
# Generator_loss:3.4255
# L1_loss:0.1350
# Discriminator_loss:0.4333
#
# EPOCH[32] - STEP[100]
# Generator_loss:5.0081
# L1_loss:0.1891
# Discriminator_loss:0.8300
#
# EPOCH[32] - STEP[200]
# Generator_loss:1.6633
# L1_loss:0.1262
# Discriminator_loss:0.6357
#
# EPOCH[33] - STEP[100]
# Generator_loss:0.6219
# L1_loss:0.1569
# Discriminator_loss:1.7337
#
# EPOCH[33] - STEP[200]
# Generator_loss:1.4861
# L1_loss:0.1557
# Discriminator_loss:0.4125
#
# EPOCH[34] - STEP[100]
# Generator_loss:1.8275
# L1_loss:0.1659
# Discriminator_loss:0.4099
#
# EPOCH[34] - STEP[200]
# Generator_loss:2.1630
# L1_loss:0.1696
# Discriminator_loss:0.2929
#
# EPOCH[35] - STEP[100]
# Generator_loss:2.0223
# L1_loss:0.1651
# Discriminator_loss:0.3102
#
# EPOCH[35] - STEP[200]
# Generator_loss:3.0374
# L1_loss:0.1865
# Discriminator_loss:0.1012
#
# EPOCH[36] - STEP[100]
# Generator_loss:1.5531
# L1_loss:0.1103
# Discriminator_loss:1.2134
#
# EPOCH[36] - STEP[200]
# Generator_loss:2.7987
# L1_loss:0.1909
# Discriminator_loss:0.2270
#
# EPOCH[37] - STEP[100]
# Generator_loss:3.1358
# L1_loss:0.1336
# Discriminator_loss:0.2443
#
# EPOCH[37] - STEP[200]
# Generator_loss:2.7666
# L1_loss:0.1407
# Discriminator_loss:0.4566
#
# EPOCH[38] - STEP[100]
# Generator_loss:2.2949
# L1_loss:0.1757
# Discriminator_loss:0.5772
#
# EPOCH[38] - STEP[200]
# Generator_loss:4.5077
# L1_loss:0.1649
# Discriminator_loss:0.4223
#
# EPOCH[39] - STEP[100]
# Generator_loss:1.8902
# L1_loss:0.1429
# Discriminator_loss:0.3750
#
# EPOCH[39] - STEP[200]
# Generator_loss:1.7806
# L1_loss:0.1368
# Discriminator_loss:0.3884
#
# EPOCH[40] - STEP[100]
# Generator_loss:3.1059
# L1_loss:0.1467
# Discriminator_loss:0.2159
#
# EPOCH[40] - STEP[200]
# Generator_loss:2.7674
# L1_loss:0.1462
# Discriminator_loss:0.4982
#
# EPOCH[41] - STEP[100]
# Generator_loss:4.1711
# L1_loss:0.1836
# Discriminator_loss:0.1238
#
# EPOCH[41] - STEP[200]
# Generator_loss:2.6881
# L1_loss:0.1427
# Discriminator_loss:0.3773
#
# EPOCH[42] - STEP[100]
# Generator_loss:3.2830
# L1_loss:0.1820
# Discriminator_loss:0.1441
#
# EPOCH[42] - STEP[200]
# Generator_loss:3.7597
# L1_loss:0.1447
# Discriminator_loss:0.7598
#
# EPOCH[43] - STEP[100]
# Generator_loss:2.0006
# L1_loss:0.1547
# Discriminator_loss:0.2747
#
# EPOCH[43] - STEP[200]
# Generator_loss:3.2716
# L1_loss:0.1610
# Discriminator_loss:0.0885
#
# EPOCH[44] - STEP[100]
# Generator_loss:1.1273
# L1_loss:0.1104
# Discriminator_loss:1.1496
#
# EPOCH[44] - STEP[200]
# Generator_loss:2.6754
# L1_loss:0.1358
# Discriminator_loss:0.6393
#
# EPOCH[45] - STEP[100]
# Generator_loss:4.3173
# L1_loss:0.1400
# Discriminator_loss:0.5899
#
# EPOCH[45] - STEP[200]
# Generator_loss:4.7834
# L1_loss:0.1635
# Discriminator_loss:0.2660
#
# EPOCH[46] - STEP[100]
# Generator_loss:3.6498
# L1_loss:0.1540
# Discriminator_loss:0.1228
#
# EPOCH[46] - STEP[200]
# Generator_loss:3.0714
# L1_loss:0.1397
# Discriminator_loss:0.7072
#
# EPOCH[47] - STEP[100]
# Generator_loss:4.0972
# L1_loss:0.1797
# Discriminator_loss:0.0717
#
# EPOCH[47] - STEP[200]
# Generator_loss:3.3413
# L1_loss:0.1232
# Discriminator_loss:1.7809
#
# EPOCH[48] - STEP[100]
# Generator_loss:1.6978
# L1_loss:0.1701
# Discriminator_loss:0.3781
#
# EPOCH[48] - STEP[200]
# Generator_loss:0.6050
# L1_loss:0.1438
# Discriminator_loss:1.0823
#
# EPOCH[49] - STEP[100]
# Generator_loss:1.4709
# L1_loss:0.1246
# Discriminator_loss:0.5673
#
# EPOCH[49] - STEP[200]
# Generator_loss:4.1383
# L1_loss:0.1524
# Discriminator_loss:0.1817
#
# EPOCH[50] - STEP[100]
# Generator_loss:3.9766
# L1_loss:0.1159
# Discriminator_loss:1.7889
#
# EPOCH[50] - STEP[200]
# Generator_loss:2.5110
# L1_loss:0.1315
# Discriminator_loss:0.4645
#
# EPOCH[51] - STEP[100]
# Generator_loss:5.0511
# L1_loss:0.1315
# Discriminator_loss:1.3866
#
# EPOCH[51] - STEP[200]
# Generator_loss:2.2363
# L1_loss:0.1552
# Discriminator_loss:0.4274
#
# EPOCH[52] - STEP[100]
# Generator_loss:1.1510
# L1_loss:0.1396
# Discriminator_loss:0.6488
#
# EPOCH[52] - STEP[200]
# Generator_loss:2.2804
# L1_loss:0.1297
# Discriminator_loss:0.7030
#
# EPOCH[53] - STEP[100]
# Generator_loss:4.6652
# L1_loss:0.1688
# Discriminator_loss:0.1027
#
# EPOCH[53] - STEP[200]
# Generator_loss:3.7728
# L1_loss:0.1324
# Discriminator_loss:0.6469
#
# EPOCH[54] - STEP[100]
# Generator_loss:3.7891
# L1_loss:0.1203
# Discriminator_loss:0.6956
#
# EPOCH[54] - STEP[200]
# Generator_loss:2.6957
# L1_loss:0.1781
# Discriminator_loss:0.2068
#
# EPOCH[55] - STEP[100]
# Generator_loss:2.3538
# L1_loss:0.1583
# Discriminator_loss:0.3586
#
# EPOCH[55] - STEP[200]
# Generator_loss:3.1176
# L1_loss:0.1349
# Discriminator_loss:0.1111
#
# EPOCH[56] - STEP[100]
# Generator_loss:4.3704
# L1_loss:0.1126
# Discriminator_loss:0.6916
#
# EPOCH[56] - STEP[200]
# Generator_loss:0.4188
# L1_loss:0.1396
# Discriminator_loss:1.5119
#
# EPOCH[57] - STEP[100]
# Generator_loss:3.3524
# L1_loss:0.1335
# Discriminator_loss:0.5792
#
# EPOCH[57] - STEP[200]
# Generator_loss:1.8517
# L1_loss:0.1414
# Discriminator_loss:0.3375
#
# EPOCH[58] - STEP[100]
# Generator_loss:5.0051
# L1_loss:0.1282
# Discriminator_loss:1.1131
#
# EPOCH[58] - STEP[200]
# Generator_loss:5.0576
# L1_loss:0.1238
# Discriminator_loss:0.7374
#
# EPOCH[59] - STEP[100]
# Generator_loss:1.6842
# L1_loss:0.1469
# Discriminator_loss:0.6356
#
# EPOCH[59] - STEP[200]
# Generator_loss:2.9634
# L1_loss:0.1844
# Discriminator_loss:0.1067
#
# EPOCH[60] - STEP[100]
# Generator_loss:3.4570
# L1_loss:0.1687
# Discriminator_loss:0.1364
#
# EPOCH[60] - STEP[200]
# Generator_loss:3.8597
# L1_loss:0.1531
# Discriminator_loss:0.3185
#
# EPOCH[61] - STEP[100]
# Generator_loss:3.0093
# L1_loss:0.1299
# Discriminator_loss:0.4732
#
# EPOCH[61] - STEP[200]
# Generator_loss:3.1105
# L1_loss:0.1747
# Discriminator_loss:0.1728
#
# EPOCH[62] - STEP[100]
# Generator_loss:2.6876
# L1_loss:0.1265
# Discriminator_loss:0.4064
#
# EPOCH[62] - STEP[200]
# Generator_loss:1.3331
# L1_loss:0.1430
# Discriminator_loss:0.5848
#
# EPOCH[63] - STEP[100]
# Generator_loss:2.4297
# L1_loss:0.1401
# Discriminator_loss:0.5308
#
# EPOCH[63] - STEP[200]
# Generator_loss:2.3230
# L1_loss:0.1201
# Discriminator_loss:0.4473
#
# EPOCH[64] - STEP[100]
# Generator_loss:3.6683
# L1_loss:0.1187
# Discriminator_loss:0.6968
#
# EPOCH[64] - STEP[200]
# Generator_loss:2.3950
# L1_loss:0.1560
# Discriminator_loss:0.1840
#
# EPOCH[65] - STEP[100]
# Generator_loss:3.2021
# L1_loss:0.1365
# Discriminator_loss:0.0871
#
# EPOCH[65] - STEP[200]
# Generator_loss:1.7088
# L1_loss:0.1468
# Discriminator_loss:0.3906
#
# EPOCH[66] - STEP[100]
# Generator_loss:2.1054
# L1_loss:0.1667
# Discriminator_loss:0.2867
#
# EPOCH[66] - STEP[200]
# Generator_loss:3.4426
# L1_loss:0.1172
# Discriminator_loss:0.2266
#
# EPOCH[67] - STEP[100]
# Generator_loss:3.6573
# L1_loss:0.1483
# Discriminator_loss:0.1577
#
# EPOCH[67] - STEP[200]
# Generator_loss:4.1803
# L1_loss:0.1235
# Discriminator_loss:0.2606
#
# EPOCH[68] - STEP[100]
# Generator_loss:2.5490
# L1_loss:0.1221
# Discriminator_loss:0.2755
#
# EPOCH[68] - STEP[200]
# Generator_loss:2.5392
# L1_loss:0.1792
# Discriminator_loss:0.1928
#
# EPOCH[69] - STEP[100]
# Generator_loss:4.8136
# L1_loss:0.1459
# Discriminator_loss:0.1534
#
# EPOCH[69] - STEP[200]
# Generator_loss:4.2970
# L1_loss:0.1392
# Discriminator_loss:0.0824
#
# EPOCH[70] - STEP[100]
# Generator_loss:7.2973
# L1_loss:0.1212
# Discriminator_loss:2.4666
#
# EPOCH[70] - STEP[200]
# Generator_loss:2.0769
# L1_loss:0.1475
# Discriminator_loss:0.2896
#
# EPOCH[71] - STEP[100]
# Generator_loss:3.4450
# L1_loss:0.1714
# Discriminator_loss:0.2781
#
# EPOCH[71] - STEP[200]
# Generator_loss:2.5610
# L1_loss:0.1370
# Discriminator_loss:0.1923
#
# EPOCH[72] - STEP[100]
# Generator_loss:0.9427
# L1_loss:0.1520
# Discriminator_loss:0.8530
#
# EPOCH[72] - STEP[200]
# Generator_loss:1.8641
# L1_loss:0.1293
# Discriminator_loss:0.6788
#
# EPOCH[73] - STEP[100]
# Generator_loss:0.4144
# L1_loss:0.1292
# Discriminator_loss:1.6259
#
# EPOCH[73] - STEP[200]
# Generator_loss:0.3659
# L1_loss:0.1218
# Discriminator_loss:1.9987
#
# EPOCH[74] - STEP[100]
# Generator_loss:1.2184
# L1_loss:0.1549
# Discriminator_loss:0.6697
#
# EPOCH[74] - STEP[200]
# Generator_loss:3.3024
# L1_loss:0.1011
# Discriminator_loss:1.1800
#
# EPOCH[75] - STEP[100]
# Generator_loss:1.0407
# L1_loss:0.1305
# Discriminator_loss:0.9220
#
# EPOCH[75] - STEP[200]
# Generator_loss:3.2261
# L1_loss:0.1166
# Discriminator_loss:0.6068
#
# EPOCH[76] - STEP[100]
# Generator_loss:2.8530
# L1_loss:0.1763
# Discriminator_loss:0.3695
#
# EPOCH[76] - STEP[200]
# Generator_loss:3.9430
# L1_loss:0.1159
# Discriminator_loss:0.2335
#
# EPOCH[77] - STEP[100]
# Generator_loss:3.2751
# L1_loss:0.1050
# Discriminator_loss:0.1603
#
# EPOCH[77] - STEP[200]
# Generator_loss:1.7130
# L1_loss:0.1618
# Discriminator_loss:0.3270
#
# EPOCH[78] - STEP[100]
# Generator_loss:1.8907
# L1_loss:0.1360
# Discriminator_loss:0.3728
#
# EPOCH[78] - STEP[200]
# Generator_loss:3.7446
# L1_loss:0.1051
# Discriminator_loss:0.6042
#
# EPOCH[79] - STEP[100]
# Generator_loss:2.0449
# L1_loss:0.1264
# Discriminator_loss:0.2443
#
# EPOCH[79] - STEP[200]
# Generator_loss:1.9684
# L1_loss:0.1481
# Discriminator_loss:0.2360
#
# EPOCH[80] - STEP[100]
# Generator_loss:3.7827
# L1_loss:0.1707
# Discriminator_loss:0.0662
#
# EPOCH[80] - STEP[200]
# Generator_loss:3.6354
# L1_loss:0.1658
# Discriminator_loss:0.0924
#
# EPOCH[81] - STEP[100]
# Generator_loss:4.0096
# L1_loss:0.1781
# Discriminator_loss:0.0601
#
# EPOCH[81] - STEP[200]
# Generator_loss:2.3129
# L1_loss:0.1286
# Discriminator_loss:0.2626
#
# EPOCH[82] - STEP[100]
# Generator_loss:2.9222
# L1_loss:0.1294
# Discriminator_loss:0.1899
#
# EPOCH[82] - STEP[200]
# Generator_loss:3.1414
# L1_loss:0.1516
# Discriminator_loss:0.1540
#
# EPOCH[83] - STEP[100]
# Generator_loss:1.9055
# L1_loss:0.1344
# Discriminator_loss:0.3250
#
# EPOCH[83] - STEP[200]
# Generator_loss:1.5505
# L1_loss:0.1286
# Discriminator_loss:0.5050
#
# EPOCH[84] - STEP[100]
# Generator_loss:4.6410
# L1_loss:0.1345
# Discriminator_loss:0.1874
#
# EPOCH[84] - STEP[200]
# Generator_loss:1.6215
# L1_loss:0.1332
# Discriminator_loss:0.4833
#
# EPOCH[85] - STEP[100]
# Generator_loss:4.8846
# L1_loss:0.1357
# Discriminator_loss:0.0442
#
# EPOCH[85] - STEP[200]
# Generator_loss:2.4893
# L1_loss:0.1357
# Discriminator_loss:0.2010
#
# EPOCH[86] - STEP[100]
# Generator_loss:3.5801
# L1_loss:0.1108
# Discriminator_loss:0.4287
#
# EPOCH[86] - STEP[200]
# Generator_loss:3.3560
# L1_loss:0.1138
# Discriminator_loss:0.3825
#
# EPOCH[87] - STEP[100]
# Generator_loss:4.6854
# L1_loss:0.1641
# Discriminator_loss:0.0293
#
# EPOCH[87] - STEP[200]
# Generator_loss:1.5625
# L1_loss:0.1072
# Discriminator_loss:0.8509
#
# EPOCH[88] - STEP[100]
# Generator_loss:2.9432
# L1_loss:0.1110
# Discriminator_loss:0.2487
#
# EPOCH[88] - STEP[200]
# Generator_loss:5.3949
# L1_loss:0.1608
# Discriminator_loss:0.0785
#
# EPOCH[89] - STEP[100]
# Generator_loss:1.6576
# L1_loss:0.1171
# Discriminator_loss:0.4851
#
# EPOCH[89] - STEP[200]
# Generator_loss:2.5127
# L1_loss:0.1190
# Discriminator_loss:0.1334
#
# EPOCH[90] - STEP[100]
# Generator_loss:3.6861
# L1_loss:0.1783
# Discriminator_loss:0.0486
#
# EPOCH[90] - STEP[200]
# Generator_loss:5.2716
# L1_loss:0.1531
# Discriminator_loss:0.0371
#
# EPOCH[91] - STEP[100]
# Generator_loss:1.2430
# L1_loss:0.1613
# Discriminator_loss:0.6776
#
# EPOCH[91] - STEP[200]
# Generator_loss:3.0103
# L1_loss:0.1156
# Discriminator_loss:0.3725
#
# EPOCH[92] - STEP[100]
# Generator_loss:3.8243
# L1_loss:0.1497
# Discriminator_loss:0.0794
#
# EPOCH[92] - STEP[200]
# Generator_loss:0.7662
# L1_loss:0.1511
# Discriminator_loss:0.9010
#
# EPOCH[93] - STEP[100]
# Generator_loss:6.4174
# L1_loss:0.1342
# Discriminator_loss:0.0522
#
# EPOCH[93] - STEP[200]
# Generator_loss:5.7548
# L1_loss:0.1490
# Discriminator_loss:0.2550
#
# EPOCH[94] - STEP[100]
# Generator_loss:1.3995
# L1_loss:0.1418
# Discriminator_loss:0.6665
#
# EPOCH[94] - STEP[200]
# Generator_loss:2.6749
# L1_loss:0.1427
# Discriminator_loss:0.9380
#
# EPOCH[95] - STEP[100]
# Generator_loss:1.1780
# L1_loss:0.1115
# Discriminator_loss:0.7399
#
# EPOCH[95] - STEP[200]
# Generator_loss:3.3472
# L1_loss:0.1293
# Discriminator_loss:0.0742
#
# EPOCH[96] - STEP[100]
# Generator_loss:2.7823
# L1_loss:0.1197
# Discriminator_loss:0.2107
#
# EPOCH[96] - STEP[200]
# Generator_loss:1.7843
# L1_loss:0.1163
# Discriminator_loss:0.4210
#
# EPOCH[97] - STEP[100]
# Generator_loss:3.8675
# L1_loss:0.1250
# Discriminator_loss:0.0945
#
# EPOCH[97] - STEP[200]
# Generator_loss:1.3503
# L1_loss:0.1177
# Discriminator_loss:0.5838
#
# EPOCH[98] - STEP[100]
# Generator_loss:3.9119
# L1_loss:0.1158
# Discriminator_loss:0.6506
#
# EPOCH[98] - STEP[200]
# Generator_loss:3.8337
# L1_loss:0.1461
# Discriminator_loss:0.0927
#
# EPOCH[99] - STEP[100]
# Generator_loss:5.3012
# L1_loss:0.1090
# Discriminator_loss:0.3826
#
# EPOCH[99] - STEP[200]
# Generator_loss:1.3174
# L1_loss:0.1129
# Discriminator_loss:1.0315
#
# EPOCH[100] - STEP[100]
# Generator_loss:4.0079
# L1_loss:0.1135
# Discriminator_loss:0.0609
#
# EPOCH[100] - STEP[200]
# Generator_loss:2.2654
# L1_loss:0.1249
# Discriminator_loss:0.2730
#
# EPOCH[101] - STEP[100]
# Generator_loss:1.3587
# L1_loss:0.1173
# Discriminator_loss:0.5065
#
# EPOCH[101] - STEP[200]
# Generator_loss:2.8381
# L1_loss:0.1313
# Discriminator_loss:0.1472
#
# EPOCH[102] - STEP[100]
# Generator_loss:5.2129
# L1_loss:0.1270
# Discriminator_loss:1.8976
#
# EPOCH[102] - STEP[200]
# Generator_loss:4.7968
# L1_loss:0.1405
# Discriminator_loss:0.1023
#
# EPOCH[103] - STEP[100]
# Generator_loss:1.3353
# L1_loss:0.1258
# Discriminator_loss:0.5422
#
# EPOCH[103] - STEP[200]
# Generator_loss:2.1282
# L1_loss:0.1218
# Discriminator_loss:0.2968
#
# EPOCH[104] - STEP[100]
# Generator_loss:4.7319
# L1_loss:0.1712
# Discriminator_loss:0.1214
#
# EPOCH[104] - STEP[200]
# Generator_loss:4.4999
# L1_loss:0.1565
# Discriminator_loss:0.3953
#
# EPOCH[105] - STEP[100]
# Generator_loss:4.2122
# L1_loss:0.1604
# Discriminator_loss:0.0612
#
# EPOCH[105] - STEP[200]
# Generator_loss:3.5696
# L1_loss:0.1563
# Discriminator_loss:0.1442
#
# EPOCH[106] - STEP[100]
# Generator_loss:8.4199
# L1_loss:0.1412
# Discriminator_loss:1.4326
#
# EPOCH[106] - STEP[200]
# Generator_loss:2.2263
# L1_loss:0.1231
# Discriminator_loss:0.2808
#
# EPOCH[107] - STEP[100]
# Generator_loss:2.0552
# L1_loss:0.1187
# Discriminator_loss:0.6368
#
# EPOCH[107] - STEP[200]
# Generator_loss:6.0084
# L1_loss:0.1679
# Discriminator_loss:0.0747
#
# EPOCH[108] - STEP[100]
# Generator_loss:0.9690
# L1_loss:0.1376
# Discriminator_loss:0.9884
#
# EPOCH[108] - STEP[200]
# Generator_loss:1.4129
# L1_loss:0.1118
# Discriminator_loss:0.6237
#
# EPOCH[109] - STEP[100]
# Generator_loss:1.1952
# L1_loss:0.1562
# Discriminator_loss:0.6857
#
# EPOCH[109] - STEP[200]
# Generator_loss:2.3336
# L1_loss:0.1153
# Discriminator_loss:0.4640
#
# EPOCH[110] - STEP[100]
# Generator_loss:1.5319
# L1_loss:0.1652
# Discriminator_loss:0.4218
#
# EPOCH[110] - STEP[200]
# Generator_loss:1.8185
# L1_loss:0.1428
# Discriminator_loss:0.3525
#
# EPOCH[111] - STEP[100]
# Generator_loss:1.2623
# L1_loss:0.1575
# Discriminator_loss:0.5865
#
# EPOCH[111] - STEP[200]
# Generator_loss:3.7742
# L1_loss:0.1307
# Discriminator_loss:0.1463
#
# EPOCH[112] - STEP[100]
# Generator_loss:4.2106
# L1_loss:0.1167
# Discriminator_loss:0.1177
#
# EPOCH[112] - STEP[200]
# Generator_loss:3.4074
# L1_loss:0.1599
# Discriminator_loss:0.0837
#
# EPOCH[113] - STEP[100]
# Generator_loss:4.7805
# L1_loss:0.1377
# Discriminator_loss:0.3177
#
# EPOCH[113] - STEP[200]
# Generator_loss:6.6269
# L1_loss:0.1108
# Discriminator_loss:0.0149
#
# EPOCH[114] - STEP[100]
# Generator_loss:4.2279
# L1_loss:0.1009
# Discriminator_loss:2.5628
#
# EPOCH[114] - STEP[200]
# Generator_loss:2.9533
# L1_loss:0.1638
# Discriminator_loss:0.1051
#
# EPOCH[115] - STEP[100]
# Generator_loss:3.2750
# L1_loss:0.1354
# Discriminator_loss:0.2212
#
# EPOCH[115] - STEP[200]
# Generator_loss:4.3626
# L1_loss:0.1337
# Discriminator_loss:0.1188
#
# EPOCH[116] - STEP[100]
# Generator_loss:3.0454
# L1_loss:0.1227
# Discriminator_loss:0.2354
#
# EPOCH[116] - STEP[200]
# Generator_loss:4.4663
# L1_loss:0.1551
# Discriminator_loss:0.0656
#
# EPOCH[117] - STEP[100]
# Generator_loss:6.7655
# L1_loss:0.1762
# Discriminator_loss:0.4552
#
# EPOCH[117] - STEP[200]
# Generator_loss:4.4352
# L1_loss:0.1315
# Discriminator_loss:0.0419
#
# EPOCH[118] - STEP[100]
# Generator_loss:7.4549
# L1_loss:0.1240
# Discriminator_loss:0.4318
#
# EPOCH[118] - STEP[200]
# Generator_loss:1.9557
# L1_loss:0.1363
# Discriminator_loss:0.9012
#
# EPOCH[119] - STEP[100]
# Generator_loss:2.7577
# L1_loss:0.1467
# Discriminator_loss:0.1460
#
# EPOCH[119] - STEP[200]
# Generator_loss:2.4587
# L1_loss:0.1308
# Discriminator_loss:0.5181
#
# EPOCH[120] - STEP[100]
# Generator_loss:3.3001
# L1_loss:0.1284
# Discriminator_loss:0.1191
#
# EPOCH[120] - STEP[200]
# Generator_loss:2.5182
# L1_loss:0.1063
# Discriminator_loss:0.3042
#
# EPOCH[121] - STEP[100]
# Generator_loss:0.6679
# L1_loss:0.1324
# Discriminator_loss:1.0821
#
# EPOCH[121] - STEP[200]
# Generator_loss:5.7271
# L1_loss:0.1587
# Discriminator_loss:0.7479
#
# EPOCH[122] - STEP[100]
# Generator_loss:4.3720
# L1_loss:0.1488
# Discriminator_loss:0.0401
#
# EPOCH[122] - STEP[200]
# Generator_loss:3.2649
# L1_loss:0.1567
# Discriminator_loss:0.0916
#
# EPOCH[123] - STEP[100]
# Generator_loss:2.6590
# L1_loss:0.1430
# Discriminator_loss:0.1874
#
# EPOCH[123] - STEP[200]
# Generator_loss:4.5467
# L1_loss:0.1244
# Discriminator_loss:0.0393
#
# EPOCH[124] - STEP[100]
# Generator_loss:4.3303
# L1_loss:0.1017
# Discriminator_loss:0.4056
#
# EPOCH[124] - STEP[200]
# Generator_loss:5.3979
# L1_loss:0.1152
# Discriminator_loss:0.1543
#
# EPOCH[125] - STEP[100]
# Generator_loss:3.2134
# L1_loss:0.1317
# Discriminator_loss:0.1078
#
# EPOCH[125] - STEP[200]
# Generator_loss:1.1643
# L1_loss:0.1380
# Discriminator_loss:0.6415
#
# EPOCH[126] - STEP[100]
# Generator_loss:3.1772
# L1_loss:0.1139
# Discriminator_loss:0.0845
#
# EPOCH[126] - STEP[200]
# Generator_loss:3.8972
# L1_loss:0.1130
# Discriminator_loss:0.2210
#
# EPOCH[127] - STEP[100]
# Generator_loss:2.8557
# L1_loss:0.1508
# Discriminator_loss:0.1120
#
# EPOCH[127] - STEP[200]
# Generator_loss:5.0168
# L1_loss:0.1815
# Discriminator_loss:0.0450
#
# EPOCH[128] - STEP[100]
# Generator_loss:1.0023
# L1_loss:0.1252
# Discriminator_loss:1.1014
#
# EPOCH[128] - STEP[200]
# Generator_loss:5.8542
# L1_loss:0.1375
# Discriminator_loss:0.0713
#
# EPOCH[129] - STEP[100]
# Generator_loss:3.5314
# L1_loss:0.0896
# Discriminator_loss:1.3577
#
# EPOCH[129] - STEP[200]
# Generator_loss:1.8759
# L1_loss:0.1208
# Discriminator_loss:0.4114
#
# EPOCH[130] - STEP[100]
# Generator_loss:2.3375
# L1_loss:0.1005
# Discriminator_loss:0.7280
#
# EPOCH[130] - STEP[200]
# Generator_loss:3.6705
# L1_loss:0.1184
# Discriminator_loss:0.2417
#
# EPOCH[131] - STEP[100]
# Generator_loss:3.7646
# L1_loss:0.1405
# Discriminator_loss:0.1914
#
# EPOCH[131] - STEP[200]
# Generator_loss:7.3870
# L1_loss:0.1667
# Discriminator_loss:0.0115
#
# EPOCH[132] - STEP[100]
# Generator_loss:3.6731
# L1_loss:0.1202
# Discriminator_loss:0.1547
#
# EPOCH[132] - STEP[200]
# Generator_loss:2.8098
# L1_loss:0.1158
# Discriminator_loss:0.6052
#
# EPOCH[133] - STEP[100]
# Generator_loss:0.6207
# L1_loss:0.1209
# Discriminator_loss:1.1125
#
# EPOCH[133] - STEP[200]
# Generator_loss:3.3910
# L1_loss:0.1098
# Discriminator_loss:0.1096
#
# EPOCH[134] - STEP[100]
# Generator_loss:5.2045
# L1_loss:0.1361
# Discriminator_loss:0.4240
#
# EPOCH[134] - STEP[200]
# Generator_loss:5.9785
# L1_loss:0.0952
# Discriminator_loss:0.3466
#
# EPOCH[135] - STEP[100]
# Generator_loss:3.2994
# L1_loss:0.1173
# Discriminator_loss:0.0883
#
# EPOCH[135] - STEP[200]
# Generator_loss:2.3293
# L1_loss:0.1396
# Discriminator_loss:0.2450
#
# EPOCH[136] - STEP[100]
# Generator_loss:6.4537
# L1_loss:0.1288
# Discriminator_loss:0.1972
#
# EPOCH[136] - STEP[200]
# Generator_loss:3.9283
# L1_loss:0.1222
# Discriminator_loss:0.0773
#
# EPOCH[137] - STEP[100]
# Generator_loss:2.6015
# L1_loss:0.1179
# Discriminator_loss:0.5140
#
# EPOCH[137] - STEP[200]
# Generator_loss:2.5435
# L1_loss:0.1350
# Discriminator_loss:0.2244
#
# EPOCH[138] - STEP[100]
# Generator_loss:2.4813
# L1_loss:0.1437
# Discriminator_loss:0.1631
#
# EPOCH[138] - STEP[200]
# Generator_loss:4.2321
# L1_loss:0.1210
# Discriminator_loss:0.2649
#
# EPOCH[139] - STEP[100]
# Generator_loss:3.3425
# L1_loss:0.1525
# Discriminator_loss:0.1217
#
# EPOCH[139] - STEP[200]
# Generator_loss:2.4217
# L1_loss:0.1318
# Discriminator_loss:0.1848
#
# EPOCH[140] - STEP[100]
# Generator_loss:2.6895
# L1_loss:0.1226
# Discriminator_loss:0.2390
#
# EPOCH[140] - STEP[200]
# Generator_loss:4.7308
# L1_loss:0.1381
# Discriminator_loss:0.6451
#
# EPOCH[141] - STEP[100]
# Generator_loss:3.4299
# L1_loss:0.1716
# Discriminator_loss:0.5368
#
# EPOCH[141] - STEP[200]
# Generator_loss:4.9204
# L1_loss:0.1266
# Discriminator_loss:0.0921
#
# EPOCH[142] - STEP[100]
# Generator_loss:5.3553
# L1_loss:0.1192
# Discriminator_loss:0.0515
#
# EPOCH[142] - STEP[200]
# Generator_loss:3.6812
# L1_loss:0.1147
# Discriminator_loss:0.1031
#
# EPOCH[143] - STEP[100]
# Generator_loss:3.3989
# L1_loss:0.1075
# Discriminator_loss:0.1838
#
# EPOCH[143] - STEP[200]
# Generator_loss:2.7522
# L1_loss:0.1197
# Discriminator_loss:0.1287
#
# EPOCH[144] - STEP[100]
# Generator_loss:0.7621
# L1_loss:0.1227
# Discriminator_loss:0.9620
#
# EPOCH[144] - STEP[200]
# Generator_loss:2.7965
# L1_loss:0.1339
# Discriminator_loss:0.1466
#
# EPOCH[145] - STEP[100]
# Generator_loss:1.6029
# L1_loss:0.1218
# Discriminator_loss:0.5566
#
# EPOCH[145] - STEP[200]
# Generator_loss:1.7128
# L1_loss:0.1379
# Discriminator_loss:0.3613
#
# EPOCH[146] - STEP[100]
# Generator_loss:4.5457
# L1_loss:0.1279
# Discriminator_loss:0.2739
#
# EPOCH[146] - STEP[200]
# Generator_loss:5.4970
# L1_loss:0.1212
# Discriminator_loss:0.1018
#
# EPOCH[147] - STEP[100]
# Generator_loss:4.5996
# L1_loss:0.1281
# Discriminator_loss:0.0399
#
# EPOCH[147] - STEP[200]
# Generator_loss:4.0334
# L1_loss:0.1314
# Discriminator_loss:0.0384
#
# EPOCH[148] - STEP[100]
# Generator_loss:2.2389
# L1_loss:0.0950
# Discriminator_loss:0.3306
#
# EPOCH[148] - STEP[200]
# Generator_loss:6.6472
# L1_loss:0.1256
# Discriminator_loss:0.0906
#
# EPOCH[149] - STEP[100]
# Generator_loss:2.3192
# L1_loss:0.1254
# Discriminator_loss:0.4715
#
# EPOCH[149] - STEP[200]
# Generator_loss:2.9842
# L1_loss:0.1321
# Discriminator_loss:0.1201
#
# EPOCH[150] - STEP[100]
# Generator_loss:4.2223
# L1_loss:0.1156
# Discriminator_loss:0.3787
#
# EPOCH[150] - STEP[200]
# Generator_loss:2.3051
# L1_loss:0.1147
# Discriminator_loss:0.2151
#
# EPOCH[151] - STEP[100]
# Generator_loss:4.9178
# L1_loss:0.1155
# Discriminator_loss:0.0589
#
# EPOCH[151] - STEP[200]
# Generator_loss:1.9348
# L1_loss:0.1247
# Discriminator_loss:0.4486
#
# EPOCH[152] - STEP[100]
# Generator_loss:4.4790
# L1_loss:0.1413
# Discriminator_loss:0.0247
#
# EPOCH[152] - STEP[200]
# Generator_loss:1.8682
# L1_loss:0.1273
# Discriminator_loss:0.2600
#
# EPOCH[153] - STEP[100]
# Generator_loss:5.1573
# L1_loss:0.1120
# Discriminator_loss:0.2286
#
# EPOCH[153] - STEP[200]
# Generator_loss:2.5379
# L1_loss:0.1200
# Discriminator_loss:0.1686
#
# EPOCH[154] - STEP[100]
# Generator_loss:1.4791
# L1_loss:0.1132
# Discriminator_loss:0.4719
#
# EPOCH[154] - STEP[200]
# Generator_loss:3.8028
# L1_loss:0.1033
# Discriminator_loss:0.2849
#
# EPOCH[155] - STEP[100]
# Generator_loss:4.9271
# L1_loss:0.1076
# Discriminator_loss:1.1602
#
# EPOCH[155] - STEP[200]
# Generator_loss:6.3650
# L1_loss:0.1407
# Discriminator_loss:0.0078
#
# EPOCH[156] - STEP[100]
# Generator_loss:2.6678
# L1_loss:0.1116
# Discriminator_loss:0.1349
#
# EPOCH[156] - STEP[200]
# Generator_loss:4.4422
# L1_loss:0.1443
# Discriminator_loss:0.0650
#
# EPOCH[157] - STEP[100]
# Generator_loss:4.3299
# L1_loss:0.1054
# Discriminator_loss:0.1230
#
# EPOCH[157] - STEP[200]
# Generator_loss:1.9610
# L1_loss:0.1050
# Discriminator_loss:0.5752
#
# EPOCH[158] - STEP[100]
# Generator_loss:2.1735
# L1_loss:0.1284
# Discriminator_loss:0.4813
#
# EPOCH[158] - STEP[200]
# Generator_loss:6.6251
# L1_loss:0.1379
# Discriminator_loss:0.0447
#
# EPOCH[159] - STEP[100]
# Generator_loss:1.0078
# L1_loss:0.1535
# Discriminator_loss:0.7648
#
# EPOCH[159] - STEP[200]
# Generator_loss:2.2805
# L1_loss:0.1114
# Discriminator_loss:0.2648
#
# EPOCH[160] - STEP[100]
# Generator_loss:3.5394
# L1_loss:0.1132
# Discriminator_loss:0.3803
#
# EPOCH[160] - STEP[200]
# Generator_loss:3.1814
# L1_loss:0.1671
# Discriminator_loss:0.1068
#
# EPOCH[161] - STEP[100]
# Generator_loss:2.8251
# L1_loss:0.1425
# Discriminator_loss:0.2414
#
# EPOCH[161] - STEP[200]
# Generator_loss:2.8468
# L1_loss:0.1417
# Discriminator_loss:0.1062
#
# EPOCH[162] - STEP[100]
# Generator_loss:2.9968
# L1_loss:0.0924
# Discriminator_loss:0.2058
#
# EPOCH[162] - STEP[200]
# Generator_loss:3.3543
# L1_loss:0.1041
# Discriminator_loss:0.0963
#
# EPOCH[163] - STEP[100]
# Generator_loss:4.0052
# L1_loss:0.1385
# Discriminator_loss:0.0432
#
# EPOCH[163] - STEP[200]
# Generator_loss:2.5940
# L1_loss:0.1206
# Discriminator_loss:0.1573
#
# EPOCH[164] - STEP[100]
# Generator_loss:3.9195
# L1_loss:0.1403
# Discriminator_loss:0.0946
#
# EPOCH[164] - STEP[200]
# Generator_loss:4.1569
# L1_loss:0.1069
# Discriminator_loss:0.1719
#
# EPOCH[165] - STEP[100]
# Generator_loss:2.6838
# L1_loss:0.1201
# Discriminator_loss:0.2950
#
# EPOCH[165] - STEP[200]
# Generator_loss:5.4252
# L1_loss:0.1231
# Discriminator_loss:0.0204
#
# EPOCH[166] - STEP[100]
# Generator_loss:1.8998
# L1_loss:0.1134
# Discriminator_loss:0.3923
#
# EPOCH[166] - STEP[200]
# Generator_loss:3.3959
# L1_loss:0.1015
# Discriminator_loss:0.1752
#
# EPOCH[167] - STEP[100]
# Generator_loss:4.7957
# L1_loss:0.1172
# Discriminator_loss:0.2355
#
# EPOCH[167] - STEP[200]
# Generator_loss:6.7185
# L1_loss:0.1172
# Discriminator_loss:1.6110
#
# EPOCH[168] - STEP[100]
# Generator_loss:4.5947
# L1_loss:0.1216
# Discriminator_loss:0.2533
#
# EPOCH[168] - STEP[200]
# Generator_loss:3.0679
# L1_loss:0.1093
# Discriminator_loss:0.1108
#
# EPOCH[169] - STEP[100]
# Generator_loss:4.2848
# L1_loss:0.1043
# Discriminator_loss:1.0721
#
# EPOCH[169] - STEP[200]
# Generator_loss:4.1367
# L1_loss:0.1313
# Discriminator_loss:0.0305
#
# EPOCH[170] - STEP[100]
# Generator_loss:3.7347
# L1_loss:0.1291
# Discriminator_loss:0.2330
#
# EPOCH[170] - STEP[200]
# Generator_loss:3.3782
# L1_loss:0.1060
# Discriminator_loss:0.2185
#
# EPOCH[171] - STEP[100]
# Generator_loss:1.1310
# L1_loss:0.1105
# Discriminator_loss:0.7634
#
# EPOCH[171] - STEP[200]
# Generator_loss:3.0950
# L1_loss:0.1209
# Discriminator_loss:0.1509
#
# EPOCH[172] - STEP[100]
# Generator_loss:2.8922
# L1_loss:0.1178
# Discriminator_loss:0.1582
#
# EPOCH[172] - STEP[200]
# Generator_loss:3.0034
# L1_loss:0.1151
# Discriminator_loss:0.1969
#
# EPOCH[173] - STEP[100]
# Generator_loss:4.0970
# L1_loss:0.1068
# Discriminator_loss:0.0804
#
# EPOCH[173] - STEP[200]
# Generator_loss:1.1015
# L1_loss:0.1266
# Discriminator_loss:0.6994
#
# EPOCH[174] - STEP[100]
# Generator_loss:6.0062
# L1_loss:0.1277
# Discriminator_loss:0.3959
#
# EPOCH[174] - STEP[200]
# Generator_loss:5.1306
# L1_loss:0.1413
# Discriminator_loss:0.0320
#
# EPOCH[175] - STEP[100]
# Generator_loss:2.9504
# L1_loss:0.1047
# Discriminator_loss:0.1721
#
# EPOCH[175] - STEP[200]
# Generator_loss:4.7309
# L1_loss:0.1446
# Discriminator_loss:0.0857
#
# EPOCH[176] - STEP[100]
# Generator_loss:2.4029
# L1_loss:0.1320
# Discriminator_loss:0.2020
#
# EPOCH[176] - STEP[200]
# Generator_loss:3.9327
# L1_loss:0.1416
# Discriminator_loss:0.0833
#
# EPOCH[177] - STEP[100]
# Generator_loss:4.7707
# L1_loss:0.0851
# Discriminator_loss:2.2809
#
# EPOCH[177] - STEP[200]
# Generator_loss:1.1143
# L1_loss:0.1592
# Discriminator_loss:0.8462
#
# EPOCH[178] - STEP[100]
# Generator_loss:5.8375
# L1_loss:0.0897
# Discriminator_loss:2.5562
#
# EPOCH[178] - STEP[200]
# Generator_loss:4.7683
# L1_loss:0.1414
# Discriminator_loss:0.0189
#
# EPOCH[179] - STEP[100]
# Generator_loss:4.3096
# L1_loss:0.1710
# Discriminator_loss:0.0735
#
# EPOCH[179] - STEP[200]
# Generator_loss:2.1376
# L1_loss:0.1384
# Discriminator_loss:0.2452
#
# EPOCH[180] - STEP[100]
# Generator_loss:2.3951
# L1_loss:0.1260
# Discriminator_loss:0.1715
#
# EPOCH[180] - STEP[200]
# Generator_loss:2.5904
# L1_loss:0.1291
# Discriminator_loss:0.1871
#
# EPOCH[181] - STEP[100]
# Generator_loss:4.2505
# L1_loss:0.1179
# Discriminator_loss:0.1656
#
# EPOCH[181] - STEP[200]
# Generator_loss:5.2685
# L1_loss:0.1233
# Discriminator_loss:0.0876
#
# EPOCH[182] - STEP[100]
# Generator_loss:7.0809
# L1_loss:0.1004
# Discriminator_loss:0.2642
#
# EPOCH[182] - STEP[200]
# Generator_loss:1.8446
# L1_loss:0.0920
# Discriminator_loss:0.4362
#
# EPOCH[183] - STEP[100]
# Generator_loss:7.0026
# L1_loss:0.1084
# Discriminator_loss:0.0617
#
# EPOCH[183] - STEP[200]
# Generator_loss:4.0768
# L1_loss:0.1806
# Discriminator_loss:0.0484
#
# EPOCH[184] - STEP[100]
# Generator_loss:6.0484
# L1_loss:0.1642
# Discriminator_loss:0.0318
#
# EPOCH[184] - STEP[200]
# Generator_loss:4.1436
# L1_loss:0.1169
# Discriminator_loss:0.0572
#
# EPOCH[185] - STEP[100]
# Generator_loss:2.8083
# L1_loss:0.1745
# Discriminator_loss:0.2716
#
# EPOCH[185] - STEP[200]
# Generator_loss:6.3759
# L1_loss:0.1082
# Discriminator_loss:1.5132
#
# EPOCH[186] - STEP[100]
# Generator_loss:2.5175
# L1_loss:0.1486
# Discriminator_loss:0.2363
#
# EPOCH[186] - STEP[200]
# Generator_loss:1.9297
# L1_loss:0.1229
# Discriminator_loss:0.3853
#
# EPOCH[187] - STEP[100]
# Generator_loss:1.1491
# L1_loss:0.1173
# Discriminator_loss:0.6744
#
# EPOCH[187] - STEP[200]
# Generator_loss:3.2442
# L1_loss:0.1260
# Discriminator_loss:0.1123
#
# EPOCH[188] - STEP[100]
# Generator_loss:4.8482
# L1_loss:0.1166
# Discriminator_loss:0.3069
#
# EPOCH[188] - STEP[200]
# Generator_loss:1.7613
# L1_loss:0.1148
# Discriminator_loss:0.3805
#
# EPOCH[189] - STEP[100]
# Generator_loss:4.3429
# L1_loss:0.1098
# Discriminator_loss:0.1107
#
# EPOCH[189] - STEP[200]
# Generator_loss:5.5177
# L1_loss:0.1099
# Discriminator_loss:0.0231
#
# EPOCH[190] - STEP[100]
# Generator_loss:1.4091
# L1_loss:0.1530
# Discriminator_loss:0.5920
#
# EPOCH[190] - STEP[200]
# Generator_loss:7.2395
# L1_loss:0.1118
# Discriminator_loss:0.3405
#
# EPOCH[191] - STEP[100]
# Generator_loss:5.3590
# L1_loss:0.1282
# Discriminator_loss:0.0938
#
# EPOCH[191] - STEP[200]
# Generator_loss:2.5363
# L1_loss:0.1467
# Discriminator_loss:0.1889
#
# EPOCH[192] - STEP[100]
# Generator_loss:3.4119
# L1_loss:0.1350
# Discriminator_loss:0.1439
#
# EPOCH[192] - STEP[200]
# Generator_loss:5.8710
# L1_loss:0.1091
# Discriminator_loss:0.1926
#
# EPOCH[193] - STEP[100]
# Generator_loss:3.1106
# L1_loss:0.1311
# Discriminator_loss:0.1425
#
# EPOCH[193] - STEP[200]
# Generator_loss:7.0922
# L1_loss:0.1316
# Discriminator_loss:0.1029
#
# EPOCH[194] - STEP[100]
# Generator_loss:3.9541
# L1_loss:0.1282
# Discriminator_loss:0.2234
#
# EPOCH[194] - STEP[200]
# Generator_loss:4.8470
# L1_loss:0.1091
# Discriminator_loss:0.0558
#
# EPOCH[195] - STEP[100]
# Generator_loss:1.3304
# L1_loss:0.1038
# Discriminator_loss:0.7950
#
# EPOCH[195] - STEP[200]
# Generator_loss:6.8958
# L1_loss:0.1087
# Discriminator_loss:0.1039
#
# EPOCH[196] - STEP[100]
# Generator_loss:2.1844
# L1_loss:0.0960
# Discriminator_loss:0.2228
#
# EPOCH[196] - STEP[200]
# Generator_loss:4.1912
# L1_loss:0.1570
# Discriminator_loss:0.0568
#
# EPOCH[197] - STEP[100]
# Generator_loss:2.7385
# L1_loss:0.1123
# Discriminator_loss:0.3024
#
# EPOCH[197] - STEP[200]
# Generator_loss:5.5254
# L1_loss:0.1194
# Discriminator_loss:0.2347
#
# EPOCH[198] - STEP[100]
# Generator_loss:4.8978
# L1_loss:0.1291
# Discriminator_loss:0.0224
#
# EPOCH[198] - STEP[200]
# Generator_loss:7.5871
# L1_loss:0.1018
# Discriminator_loss:0.7873
#
# EPOCH[199] - STEP[100]
# Generator_loss:2.2284
# L1_loss:0.1137
# Discriminator_loss:0.2504
#
# EPOCH[199] - STEP[200]
# Generator_loss:3.9549
# L1_loss:0.1084
# Discriminator_loss:0.1902
#
# EPOCH[200] - STEP[100]
# Generator_loss:6.3388
# L1_loss:0.1171
# Discriminator_loss:0.7981
#
# EPOCH[200] - STEP[200]
# Generator_loss:3.5536
# L1_loss:0.1193
# Discriminator_loss:0.1059

# %%
test_ind = 2
val_path = os.getenv('HOME')+'/aiffel/cGAN/data/cityscapes/val'

f = data_path + os.listdir(val_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
